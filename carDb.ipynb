-- %% [markdown]
-- # [CarSoheilDb]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [CarSoheilDb]    Script Date: 22/04/1403 11:00:48 ب.ظ ******/
CREATE DATABASE [CarSoheilDb]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'CarSoheilDb', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\CarSoheilDb.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'CarSoheilDb_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\CarSoheilDb_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [CarSoheilDb] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [CarSoheilDb].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [CarSoheilDb] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [CarSoheilDb] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [CarSoheilDb] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [CarSoheilDb] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [CarSoheilDb] SET ARITHABORT OFF 
GO
ALTER DATABASE [CarSoheilDb] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [CarSoheilDb] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [CarSoheilDb] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [CarSoheilDb] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [CarSoheilDb] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [CarSoheilDb] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [CarSoheilDb] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [CarSoheilDb] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [CarSoheilDb] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [CarSoheilDb] SET  ENABLE_BROKER 
GO
ALTER DATABASE [CarSoheilDb] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [CarSoheilDb] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [CarSoheilDb] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [CarSoheilDb] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [CarSoheilDb] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [CarSoheilDb] SET READ_COMMITTED_SNAPSHOT ON 
GO
ALTER DATABASE [CarSoheilDb] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [CarSoheilDb] SET RECOVERY FULL 
GO
ALTER DATABASE [CarSoheilDb] SET  MULTI_USER 
GO
ALTER DATABASE [CarSoheilDb] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [CarSoheilDb] SET DB_CHAINING OFF 
GO
ALTER DATABASE [CarSoheilDb] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [CarSoheilDb] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [CarSoheilDb] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [CarSoheilDb] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'CarSoheilDb', N'ON'
GO
ALTER DATABASE [CarSoheilDb] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[__EFMigrationsHistory]

-- %%
USE [CarSoheilDb]
GO

-- %%
/****** Object:  Table [dbo].[__EFMigrationsHistory]    Script Date: 22/04/1403 11:00:49 ب.ظ ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[__EFMigrationsHistory](
	[MigrationId] [nvarchar](150) NOT NULL,
	[ProductVersion] [nvarchar](32) NOT NULL,
 CONSTRAINT [PK___EFMigrationsHistory] PRIMARY KEY CLUSTERED 
(
	[MigrationId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Product]

-- %%
/****** Object:  Table [dbo].[Product]    Script Date: 22/04/1403 11:00:49 ب.ظ ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Product](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Company] [nvarchar](max) NOT NULL,
	[Model] [nvarchar](max) NOT NULL,
	[Color] [nvarchar](max) NOT NULL,
	[Number_Plate] [nvarchar](max) NOT NULL,
	[Details] [nvarchar](max) NOT NULL,
	[Phone_Number] [nvarchar](max) NOT NULL,
	[Photo] [nvarchar](max) NOT NULL,
	[Creation_Date] [datetime2](7) NOT NULL,
 CONSTRAINT [PK_Product] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [CarSoheilDb]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [CarSoheilDb] SET  READ_WRITE 
GO
